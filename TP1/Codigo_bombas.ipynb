# %% [markdown]
# <a href="https://colab.research.google.com/github/Camilo99B/Seleccion-de-Bombas-en-Ingenieria-Mecanica-Integrando-la-Ley-de-Similitud-y-la-IA-con-ChatGPT/blob/main/TP1/Codigo_bombas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("BIENVENIDO.")
print("")
print("Hola, tengo el proposito de ayudarle a elegir la bomba mas adecuada.")
print("")
# Datos de la bomba base
H1 = float(input("Ingrese la cabeza de la bomba de referencia (H1) en m: "))
Q1 = float(input("Ingrese el caudal de la bomba de referencia (Q1) en m3/s: "))
N1 = float(input("Ingrese las RPM de la bomba de referencia (N1) en rpm: "))
P1 = float(input("Ingrese la potencia de la bomba de referencia (P1) en kW: "))

# Solicitar al usuario el parámetro secundario para la segunda bomba (caudal, potencia, RPM o cabeza)
parametro_secundario2 = input("Seleccione el parámetro secundario a ingresar para la segunda bomba (caudal, potencia, RPM o cabeza): ")

if parametro_secundario2 == "cabeza":
    H2 = float(input("Ingrese la cabeza de la bomba nueva (H2) en m: "))
    N2 = N1 * ((H2 / H1) ** 0.5)
    Q2 = Q1 * (N2 / N1)
    P2 = P1 * ((N2 / N1) ** 3) # Cálculo de potencia basado en la Ley de Similitud

elif parametro_secundario2 == "caudal":
    Q2 = float(input("Ingrese el caudal de la bomba nueva (Q2) en m3/s: "))
    N2 = (Q2 / Q1) * N1
    P2 = P1 * ((N2 / N1) ** 3)  # Cálculo de potencia basado en la Ley de Similitud
    H2 = H1 * ((N2 / N1) ** 2)

elif parametro_secundario2 == "potencia":
    P2 = float(input("Ingrese la potencia de la bomba nueva (P2) en kW: "))
    N2 = N1 * ((P2 / P1) ** (1/3))
    Q2 = Q1 * (N2 / N1)
    H2 = H1 * ((N2 / N1) ** 2)

elif parametro_secundario2 == "rpm":
    N2 = float(input("Ingrese las RPM de la bomba nueva (N2) en rpm: "))
    Q2 = Q1 * (N2 / N1)
    H2 = H1 * ((N2 / N1) ** 2)
    P2 = P1 * ((N2 / N1) ** 3)  # Cálculo de potencia basado en la Ley de Similitud

# Mostrar los resultados
print("Valores de la segunda bomba: ")
print("")
print("Cabeza (H2): ",H2,"m")
print("Caudal (Q2): ",Q2,"m3/s")
print("RPM (N2): ",N2,"rpm")
print("Potencia (P2): ",P2,"kW")
print("")

# Base de datos ficticia de bombas (50 bombas)
catalogo_bombas = {
    100345: {'Nombre': 'Bomba BCS001', 'H': 100, 'Q': 200, 'N': 1750, 'P': 15},
    100987: {'Nombre': 'Bomba BCM002', 'H': 150, 'Q': 250, 'N': 1800, 'P': 20},
    100876: {'Nombre': 'Bomba BCB003', 'H': 110, 'Q': 220, 'N': 1760, 'P': 16},
    100249: {'Nombre': 'Bomba BCS004', 'H': 160, 'Q': 260, 'N': 1850, 'P': 22},
    100962: {'Nombre': 'Bomba BCM005', 'H': 130, 'Q': 210, 'N': 1780, 'P': 18},
    100981: {'Nombre': 'Bomba BCB006', 'H': 155, 'Q': 240, 'N': 1820, 'P': 19},
    100249: {'Nombre': 'Bomba BCS007', 'H': 120, 'Q': 230, 'N': 1770, 'P': 17},
    205688: {'Nombre': 'Bomba BCX092', 'H': 190, 'Q': 202, 'N': 1765, 'P': 17.5},
    205804: {'Nombre': 'Bomba BCX093', 'H': 147, 'Q': 300, 'N': 1790, 'P': 19.0},
    205437: {'Nombre': 'Bomba BCX094', 'H': 122, 'Q': 208, 'N': 1767, 'P': 17.7},
    205421: {'Nombre': 'Bomba BCB095', 'H': 210, 'Q': 200, 'N': 1760, 'P': 17.0},
    205095: {'Nombre': 'Bomba BCE096', 'H': 141, 'Q': 228, 'N': 1792, 'P': 19.2},
    205886: {'Nombre': 'Bomba BCB097', 'H': 129, 'Q': 214, 'N': 1776, 'P': 17.6},
    205340: {'Nombre': 'Bomba BCB098', 'H': 210, 'Q': 244, 'N': 1801, 'P': 20.1},
    205877: {'Nombre': 'Bomba BCB099', 'H': 135, 'Q': 222, 'N': 1781, 'P': 18.3},
    205055: {'Nombre': 'Bomba BCB100', 'H': 130, 'Q': 218, 'N': 1777, 'P': 18.0},
}

# Valores calculados para la segunda bomba
H2_calculado = H2
Q2_calculado = Q2
N2_calculado = N2
P2_calculado = P2

# Umbral de similitud (ajusta según tus criterios)
umbral_similitud = 15

# Lista para almacenar las bombas recomendadas
bombas_recomendadas = []

# Comparar los valores calculados con el catálogo de bombas
for bomba, parametros in catalogo_bombas.items():
    similitud = abs(parametros['H'] - H2_calculado) + abs(parametros['Q'] - Q2_calculado) + abs(parametros['N'] - N2_calculado) + abs(parametros['P'] - P2_calculado)
    if similitud <= umbral_similitud:
        bombas_recomendadas.append(bomba)

# Mostrar las bombas recomendadas
if bombas_recomendadas:
    print("Bombas recomendadas:")
    for bomba in bombas_recomendadas:
        propiedades = catalogo_bombas[bomba]
        print(f'Bomba ID: PUMP - {bomba}')
        print(f'Nombre: {propiedades["Nombre"]}')
        print(f'H: {propiedades["H"]}',"m")
        print(f'Q: {propiedades["Q"]}',"m3/s")
        print(f'N: {propiedades["N"]}', "rpm")
        print(f'P: {propiedades["P"]}',"kW")
        print('---')
else:
    print("No se encontraron bombas recomendadas para los valores calculados.")
# Out:
# BIENVENIDO.
#
# Hola, tengo el proposito de ayudarle a elegir la bomba mas adecuada.
#
# Ingrese la cabeza de la bomba de referencia (H1) en m: 160
# Ingrese el caudal de la bomba de referencia (Q1) en m3/s: 300
# Ingrese las RPM de la bomba de referencia (N1) en rpm: 1750
# Ingrese la potencia de la bomba de referencia (P1) en kW: 20
# Seleccione el parámetro secundario a ingresar para la segunda bomba (caudal, potencia, RPM o cabeza): rpm
# Ingrese las RPM de la bomba nueva (N2) en rpm: 2000
# Valores de la segunda bomba:
#
# Cabeza (H2):  208.97959183673467 m
# Caudal (Q2):  342.85714285714283 m3/s
# RPM (N2):  2000.0 rpm
# Potencia (P2):  29.85422740524781 kW
#
# Bombas recomendadas:
# Bomba ID: PUMP - 200865
# Nombre: Bomba BCX083
# H: 205 m
# Q: 340 m3/s
# N: 2001 rpm
# P: 28.4 kW
# ---
# Bomba ID: PUMP - 200543
# Nombre: Bomba BCX089
# H: 205 m
# Q: 346 m3/s
# N: 1997 rpm
# P: 30.7 kW
# ---
